# %%
import pandas as pd

# %%
acs_dp04 = pd.read_csv('E:/CR2/Repos/TNC-Demand-Model-Southeast/Raw_Inputs/ACS/DP04/DP04.csv')

# %%
acs_dp04.head()
# Out:
#                  GEO_ID                                         NAME  \
# 0             Geography                         Geographic Area Name
# 1           0400000US21                                     Kentucky
# 2  1400000US21067000101  Census Tract 1.01, Fayette County, Kentucky
# 3  1400000US21067000102  Census Tract 1.02, Fayette County, Kentucky
# 4  1400000US21067000200     Census Tract 2, Fayette County, Kentucky
#
#                                          DP04_0001E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                           1983949
# 2                                              2193
# 3                                              1184
# 4                                              1465
#
#                                           DP04_0001M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                                362
# 2                                                 83
# 3                                                 68
# 4                                                107
#
#                                           DP04_0002E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                            1734618
# 2                                               1993
# 3                                                984
# 4                                               1225
#
#                                           DP04_0002M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                               4886
# 2                                                120
# 3                                                108
# 4                                                128
#
#                                           DP04_0003E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                             249331
# 2                                                200
# 3                                                200
# 4                                                240
#
#                                           DP04_0003M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                               4892
# 2                                                 86
# 3                                                 91
# 4                                                103
#
#                                           DP04_0004E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                                1.6
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#                                           DP04_0004M  ...  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...  ...
# 1                                                0.1  ...
# 2                                               11.0  ...
# 3                                                9.9  ...
# 4                                                9.7  ...
#
#                                          DP04_0139PM  \
# 0  Percent Margin of Error!!GROSS RENT AS A PERCE...
# 1                                                0.3
# 2                                                3.8
# 3                                                5.9
# 4                                                4.1
#
#                                          DP04_0140PE  \
# 0  Percent!!GROSS RENT AS A PERCENTAGE OF HOUSEHO...
# 1                                               11.5
# 2                                                9.5
# 3                                               20.4
# 4                                               21.7
#
#                                          DP04_0140PM  \
# 0  Percent Margin of Error!!GROSS RENT AS A PERCE...
# 1                                                0.3
# 2                                                3.3
# 3                                                9.3
# 4                                                8.9
#
#                                          DP04_0141PE  \
# 0  Percent!!GROSS RENT AS A PERCENTAGE OF HOUSEHO...
# 1                                                8.6
# 2                                               12.6
# 3                                               12.3
# 4                                                6.7
#
#                                          DP04_0141PM  \
# 0  Percent Margin of Error!!GROSS RENT AS A PERCE...
# 1                                                0.3
# 2                                                5.3
# 3                                                7.1
# 4                                                6.1
#
#                                          DP04_0142PE  \
# 0  Percent!!GROSS RENT AS A PERCENTAGE OF HOUSEHO...
# 1                                               36.0
# 2                                               42.7
# 3                                               29.0
# 4                                               41.1
#
#                                          DP04_0142PM  \
# 0  Percent Margin of Error!!GROSS RENT AS A PERCE...
# 1                                                0.5
# 2                                                6.7
# 3                                               11.8
# 4                                               10.6
#
#                                          DP04_0143PE  \
# 0  Percent!!GROSS RENT AS A PERCENTAGE OF HOUSEHO...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP04_0143PM Unnamed: 574
# 0  Percent Margin of Error!!GROSS RENT AS A PERCE...          NaN
# 1                                                (X)          NaN
# 2                                                (X)          NaN
# 3                                                (X)          NaN
# 4                                                (X)          NaN
#
# [5 rows x 575 columns]

# %%
acs_dp04[['TRACT', 'COUNTY', 'STATE']] = acs_dp04.NAME.str.split(',', expand=True)

# %%
acs_dp04 = acs_dp04[acs_dp04['COUNTY'] == ' Fayette County']

# %%
acs_dp04['CENSUS_TRACT'] = acs_dp04.apply(lambda row: row['GEO_ID'][9:], axis = 1)

# %%
acs_dp04.CENSUS_TRACT.head()
# Out:
# 2    21067000101
# 3    21067000102
# 4    21067000200
# 5    21067000300
# 6    21067000400
# Name: CENSUS_TRACT, dtype: object

# %%
rename = ['TOTAL_HHLDS', 'HHLDS_0_VEH', 'HHLDS_1_VEH', 'HHLDS_2_VEH', 'HHLDS_3P_VEH', 'CENSUS_TRACT']

# %%
keep = ['DP04_0057E', 'DP04_0058E', 'DP04_0059E', 'DP04_0060E', 'DP04_0061E', 'CENSUS_TRACT']

# %%
acs_dp04 = acs_dp04[keep]

# %%
acs_dp04.columns = rename

# %%
acs_dp04.head()
# Out:
#   TOTAL_HHLDS HHLDS_0_VEH HHLDS_1_VEH HHLDS_2_VEH HHLDS_3P_VEH CENSUS_TRACT
# 2        1993         646         950         358           39  21067000101
# 3         984         323         478         129           54  21067000102
# 4        1225         355         449         290          131  21067000200
# 5        1249         227         595         307          120  21067000300
# 6         784         215         321         186           62  21067000400

# %%
#THIS ALL NEEDS TO GO IN THE MAIN SCRIPT

acs_dp04['HHLDS_0_VEH'] = acs_dp04.HHLDS_0_VEH.astype(float)
acs_dp04['HHLDS_1_VEH'] = acs_dp04.HHLDS_1_VEH.astype(float)
acs_dp04['HHLDS_2_VEH'] = acs_dp04.HHLDS_2_VEH.astype(float)
acs_dp04['HHLDS_3P_VEH'] = acs_dp04.HHLDS_3P_VEH.astype(float)
acs_dp04['TOTAL_HHLDS'] = acs_dp04.TOTAL_HHLDS.astype(float)

# %%
#THIS ALL NEEDS TO GO IN THE MAIN SCRIPT

def set_avg_veh_per_hhlds(row):
    if row['TOTAL_HHLDS']  == 0:
        veh = 0
        
    else:
        veh = (row['HHLDS_0_VEH']*0 + row['HHLDS_1_VEH']*1 + row['HHLDS_2_VEH']*2 + row['HHLDS_3P_VEH']*3)/row['TOTAL_HHLDS']
        
    return veh

# %%
#THIS ALL NEEDS TO GO IN THE MAIN SCRIPT

acs_dp04['AVG_VEH_PER_HHLD'] = acs_dp04.apply(lambda row: set_avg_veh_per_hhlds(row), axis = 1)

# %%
acs_dp04.head()
# Out:
#    TOTAL_HHLDS  HHLDS_0_VEH  HHLDS_1_VEH  HHLDS_2_VEH  HHLDS_3P_VEH  \
# 2       1993.0        646.0        950.0        358.0          39.0
# 3        984.0        323.0        478.0        129.0          54.0
# 4       1225.0        355.0        449.0        290.0         131.0
# 5       1249.0        227.0        595.0        307.0         120.0
# 6        784.0        215.0        321.0        186.0          62.0
#
#   CENSUS_TRACT  AVG_VEH_PER_HHLD
# 2  21067000101          0.894631
# 3  21067000102          0.912602
# 4  21067000200          1.160816
# 5  21067000300          1.256205
# 6  21067000400          1.121173

# %%
acs_dp05 = pd.read_csv('E:/CR2/Repos/TNC-Demand-Model-Southeast/Raw_Inputs/ACS/DP05/DP05.csv')

# %%
acs_dp05.head()
# Out:
#                  GEO_ID                                         NAME  \
# 0             Geography                         Geographic Area Name
# 1           0400000US21                                     Kentucky
# 2  1400000US21067000101  Census Tract 1.01, Fayette County, Kentucky
# 3  1400000US21067000102  Census Tract 1.02, Fayette County, Kentucky
# 4  1400000US21067000200     Census Tract 2, Fayette County, Kentucky
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                  4449052
# 2                                     3171
# 3                                     1546
# 4                                     3839
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                           *****
# 2                                             264
# 3                                             272
# 4                                             467
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                        2190922
# 2                                           1835
# 3                                            838
# 4                                           2059
#
#                                           DP05_0002M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               1184
# 2                                                252
# 3                                                131
# 4                                                368
#
#                                         DP05_0003E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                          2258130
# 2                                             1336
# 3                                              708
# 4                                             1780
#
#                                           DP05_0003M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               1184
# 2                                                169
# 3                                                218
# 4                                                298
#
#                                           DP05_0004E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# 1                                               97.0
# 2                                              137.4
# 3                                              118.4
# 4                                              115.7
#
#                                           DP05_0004M  ...  \
# 0  Margin of Error!!SEX AND AGE!!Total population...  ...
# 1                                                0.1  ...
# 2                                               28.6  ...
# 3                                               38.9  ...
# 4                                               28.7  ...
#
#                                          DP05_0085PM  \
# 0  Percent Margin of Error!!HISPANIC OR LATINO AN...
# 1                                                0.1
# 2                                                2.2
# 3                                                1.8
# 4                                                4.6
#
#                     DP05_0086PE                                   DP05_0086PM  \
# 0  Percent!!Total housing units  Percent Margin of Error!!Total housing units
# 1                           (X)                                           (X)
# 2                           (X)                                           (X)
# 3                           (X)                                           (X)
# 4                           (X)                                           (X)
#
#                                          DP05_0087PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                            3349115
# 2                                               2883
# 3                                               1371
# 4                                               3172
#
#                                          DP05_0087PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP05_0088PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               48.5
# 2                                               57.0
# 3                                               53.6
# 4                                               53.9
#
#                                          DP05_0088PM  \
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...
# 1                                                0.1
# 2                                                5.5
# 3                                                8.7
# 4                                                7.1
#
#                                          DP05_0089PE  \
# 0  Percent!!CITIZEN, VOTING AGE POPULATION!!Citiz...
# 1                                               51.5
# 2                                               43.0
# 3                                               46.4
# 4                                               46.1
#
#                                          DP05_0089PM Unnamed: 358
# 0  Percent Margin of Error!!CITIZEN, VOTING AGE P...          NaN
# 1                                                0.1          NaN
# 2                                                5.5          NaN
# 3                                                8.7          NaN
# 4                                                7.1          NaN
#
# [5 rows x 359 columns]

# %%
acs_dp05[['TRACT', 'COUNTY', 'STATE']] = acs_dp05.NAME.str.split(',', expand=True)

# %%
acs_dp05 = acs_dp05[acs_dp05['COUNTY'] == ' Fayette County']

# %%
acs_dp05.head()
# Out:
#                  GEO_ID                                         NAME  \
# 2  1400000US21067000101  Census Tract 1.01, Fayette County, Kentucky
# 3  1400000US21067000102  Census Tract 1.02, Fayette County, Kentucky
# 4  1400000US21067000200     Census Tract 2, Fayette County, Kentucky
# 5  1400000US21067000300     Census Tract 3, Fayette County, Kentucky
# 6  1400000US21067000400     Census Tract 4, Fayette County, Kentucky
#
#   DP05_0001E DP05_0001M DP05_0002E DP05_0002M DP05_0003E DP05_0003M  \
# 2       3171        264       1835        252       1336        169
# 3       1546        272        838        131        708        218
# 4       3839        467       2059        368       1780        298
# 5       2716        314       1262        224       1454        174
# 6       1960        185        831        117       1129        142
#
#   DP05_0004E DP05_0004M  ... DP05_0087PE DP05_0087PM DP05_0088PE DP05_0088PM  \
# 2      137.4       28.6  ...        2883         (X)        57.0         5.5
# 3      118.4       38.9  ...        1371         (X)        53.6         8.7
# 4      115.7       28.7  ...        3172         (X)        53.9         7.1
# 5       86.8       16.4  ...        2047         (X)        46.6         5.8
# 6       73.6       13.7  ...        1243         (X)        37.2         6.1
#
#   DP05_0089PE DP05_0089PM Unnamed: 358              TRACT           COUNTY  \
# 2        43.0         5.5          NaN  Census Tract 1.01   Fayette County
# 3        46.4         8.7          NaN  Census Tract 1.02   Fayette County
# 4        46.1         7.1          NaN     Census Tract 2   Fayette County
# 5        53.4         5.8          NaN     Census Tract 3   Fayette County
# 6        62.8         6.1          NaN     Census Tract 4   Fayette County
#
#        STATE
# 2   Kentucky
# 3   Kentucky
# 4   Kentucky
# 5   Kentucky
# 6   Kentucky
#
# [5 rows x 362 columns]

# %%
acs_dp05['CENSUS_TRACT'] = acs_dp05.apply(lambda row: row['GEO_ID'][9:], axis = 1)

# %%
acs_dp05.CENSUS_TRACT.head()
# Out:
# 2    21067000101
# 3    21067000102
# 4    21067000200
# 5    21067000300
# 6    21067000400
# Name: CENSUS_TRACT, dtype: object

# %%
rename = ['TOTAL_POP', 'TOTAL_MALE', 'TOTAL_FEMALE', 'AGE_5U', 'AGE_5_9', 'AGE+10_14', 'AGE_15_19', 'AGE_20_24', 'AGE_25_34', 'AGE_35_44', 'AGE_45_54', 'AGE_55_59', 'AGE_60_64', 'AGE_65_74', 'AGE_75_84', 'AGE_85P', 'MEDIAN_AGE', 'CENSUS_TRACT']

# %%
keep = ['DP05_0001E', 'DP05_0002E', 'DP05_0003E', 'DP05_0005E', 'DP05_0006E', 'DP05_0007E','DP05_0008E', 'DP05_0009E', 'DP05_0010E', 'DP05_0011E', 'DP05_0012E', 'DP05_0013E', 'DP05_0014E', 'DP05_0015E', 'DP05_0016E', 'DP05_0017E', 'DP05_0018E', 'CENSUS_TRACT']

# %%
acs_dp05 = acs_dp05[keep]

# %%
acs_dp05.columns = rename

# %%
acs_dp05.head()
# Out:
#   TOTAL_POP TOTAL_MALE TOTAL_FEMALE AGE_5U AGE_5_9 AGE+10_14 AGE_15_19  \
# 2      3171       1835         1336    100      50        36        97
# 3      1546        838          708     51      59        22        20
# 4      3839       2059         1780    129     136       185       815
# 5      2716       1262         1454    145     168       138       151
# 6      1960        831         1129    218     164       149       126
#
#   AGE_20_24 AGE_25_34 AGE_35_44 AGE_45_54 AGE_55_59 AGE_60_64 AGE_65_74  \
# 2       752       727       371       253       146       279       249
# 3        20       281       189       219       134        80       297
# 4       749       521       250       434       223       126       246
# 5       203       446       456       264       219       258       213
# 6       103       316       265       199        84       111       116
#
#   AGE_75_84 AGE_85P MEDIAN_AGE CENSUS_TRACT
# 2        91      20       31.0  21067000101
# 3        93      81       52.4  21067000102
# 4        18       7       24.1  21067000200
# 5         8      47       36.8  21067000300
# 6       105       4       32.8  21067000400

# %%
acs_s1101 = pd.read_csv('E:/CR2/Repos/TNC-Demand-Model-Southeast/Raw_Inputs/ACS/S1101/S1101.csv')

# %%
acs_s1101.head()
# Out:
#                  GEO_ID                                         NAME  \
# 0             Geography                         Geographic Area Name
# 1           0400000US21                                     Kentucky
# 2  1400000US21067000101  Census Tract 1.01, Fayette County, Kentucky
# 3  1400000US21067000102  Census Tract 1.02, Fayette County, Kentucky
# 4  1400000US21067000200     Census Tract 2, Fayette County, Kentucky
#
#                                   S1101_C01_001E  \
# 0  Estimate!!Total!!HOUSEHOLDS!!Total households
# 1                                        1734618
# 2                                           1993
# 3                                            984
# 4                                           1225
#
#                                       S1101_C01_001M  \
# 0  Margin of Error!!Total!!HOUSEHOLDS!!Total hous...
# 1                                               4886
# 2                                                120
# 3                                                108
# 4                                                128
#
#                                       S1101_C01_002E  \
# 0  Estimate!!Total!!HOUSEHOLDS!!Average household...
# 1                                               2.49
# 2                                               1.52
# 3                                               1.44
# 4                                               2.37
#
#                                       S1101_C01_002M  \
# 0  Margin of Error!!Total!!HOUSEHOLDS!!Average ho...
# 1                                               0.01
# 2                                               0.10
# 3                                               0.10
# 4                                               0.30
#
#                               S1101_C01_003E  \
# 0  Estimate!!Total!!FAMILIES!!Total families
# 1                                    1135835
# 2                                        437
# 3                                        187
# 4                                        477
#
#                                      S1101_C01_003M  \
# 0  Margin of Error!!Total!!FAMILIES!!Total families
# 1                                              5114
# 2                                                87
# 3                                                49
# 4                                                95
#
#                                    S1101_C01_004E  \
# 0  Estimate!!Total!!FAMILIES!!Average family size
# 1                                            3.05
# 2                                            2.40
# 3                                            2.70
# 4                                            3.33
#
#                                       S1101_C01_004M  ...  \
# 0  Margin of Error!!Total!!FAMILIES!!Average fami...  ...
# 1                                               0.01  ...
# 2                                               0.21  ...
# 3                                               0.29  ...
# 4                                               0.49  ...
#
#                                       S1101_C05_014M  \
# 0  Margin of Error!!Nonfamily household!!Total ho...
# 1                                                0.4
# 2                                                2.5
# 3                                                6.8
# 4                                               10.6
#
#                                       S1101_C05_015E  \
# 0  Estimate!!Nonfamily household!!Total household...
# 1                                               32.0
# 2                                               93.6
# 3                                               83.6
# 4                                               59.4
#
#                                       S1101_C05_015M  \
# 0  Margin of Error!!Nonfamily household!!Total ho...
# 1                                                0.4
# 2                                                2.5
# 3                                                7.1
# 4                                               10.6
#
#                                       S1101_C05_016E  \
# 0  Estimate!!Nonfamily household!!Total household...
# 1                                               10.6
# 2                                                0.0
# 3                                                1.6
# 4                                                0.0
#
#                                       S1101_C05_016M  \
# 0  Margin of Error!!Nonfamily household!!Total ho...
# 1                                                0.2
# 2                                                1.9
# 3                                                2.7
# 4                                                3.9
#
#                                       S1101_C05_017E  \
# 0  Estimate!!Nonfamily household!!Total household...
# 1                                               53.8
# 2                                                8.5
# 3                                               21.8
# 4                                               15.8
#
#                                       S1101_C05_017M  \
# 0  Margin of Error!!Nonfamily household!!Total ho...
# 1                                                0.5
# 2                                                3.4
# 3                                                9.2
# 4                                                7.4
#
#                                       S1101_C05_018E  \
# 0  Estimate!!Nonfamily household!!Total household...
# 1                                               46.2
# 2                                               91.5
# 3                                               78.2
# 4                                               84.2
#
#                                       S1101_C05_018M Unnamed: 182
# 0  Margin of Error!!Nonfamily household!!Total ho...          NaN
# 1                                                0.5          NaN
# 2                                                3.4          NaN
# 3                                                9.2          NaN
# 4                                                7.4          NaN
#
# [5 rows x 183 columns]

# %%
acs_s1101[['TRACT', 'COUNTY', 'STATE']] = acs_s1101.NAME.str.split(',', expand=True)

# %%
acs_s1101 = acs_s1101[acs_s1101['COUNTY'] == ' Fayette County']

# %%
acs_s1101['CENSUS_TRACT'] = acs_s1101.apply(lambda row: row['GEO_ID'][9:], axis = 1)

# %%
keep = ['S1101_C01_001E', 'S1101_C01_002E', 'S1101_C01_004E', 'CENSUS_TRACT']

# %%
rename = ['TOTAL_HHLDS', 'AVG_HHLD_SIZE', 'AVG_FAMILY_SIZE', 'CENSUS_TRACT']

# %%
acs_s1101 = acs_s1101[keep]
acs_s1101.columns = rename

# %%
acs_s1501 = pd.read_csv('E:/CR2/Repos/TNC-Demand-Model-Southeast/Raw_Inputs/ACS/S1501/S1501.csv')

# %%
acs_s1501.head()
# Out:
#                  GEO_ID                                         NAME  \
# 0             Geography                         Geographic Area Name
# 1           0400000US21                                     Kentucky
# 2  1400000US21067000101  Census Tract 1.01, Fayette County, Kentucky
# 3  1400000US21067000102  Census Tract 1.02, Fayette County, Kentucky
# 4  1400000US21067000200     Census Tract 2, Fayette County, Kentucky
#
#                                       S1501_C01_001E  \
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                             420653
# 2                                                820
# 3                                                 20
# 4                                               1416
#
#                                       S1501_C01_001M  \
# 0  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# 1                                               1135
# 2                                                216
# 3                                                 16
# 4                                                310
#
#                                       S1501_C01_002E  \
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                              52327
# 2                                                 14
# 3                                                  0
# 4                                                 13
#
#                                       S1501_C01_002M  \
# 0  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# 1                                               1771
# 2                                                 22
# 3                                                 11
# 4                                                 20
#
#                                       S1501_C01_003E  \
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                             151057
# 2                                                 86
# 3                                                  0
# 4                                                425
#
#                                       S1501_C01_003M  \
# 0  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# 1                                               2706
# 2                                                 52
# 3                                                 11
# 4                                                157
#
#                                       S1501_C01_004E  \
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                             179972
# 2                                                510
# 3                                                 11
# 4                                                846
#
#                                       S1501_C01_004M  ...  \
# 0  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...  ...
# 1                                               2510  ...
# 2                                                195  ...
# 3                                                 18  ...
# 4                                                282  ...
#
#                                       S1501_C06_060M  \
# 0  Margin of Error!!Percent Female!!MEDIAN EARNIN...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1501_C06_061E  \
# 0  Estimate!!Percent Female!!MEDIAN EARNINGS IN T...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1501_C06_061M  \
# 0  Margin of Error!!Percent Female!!MEDIAN EARNIN...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1501_C06_062E  \
# 0  Estimate!!Percent Female!!MEDIAN EARNINGS IN T...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1501_C06_062M  \
# 0  Margin of Error!!Percent Female!!MEDIAN EARNIN...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1501_C06_063E  \
# 0  Estimate!!Percent Female!!MEDIAN EARNINGS IN T...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1501_C06_063M  \
# 0  Margin of Error!!Percent Female!!MEDIAN EARNIN...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1501_C06_064E  \
# 0  Estimate!!Percent Female!!MEDIAN EARNINGS IN T...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1501_C06_064M Unnamed: 770
# 0  Margin of Error!!Percent Female!!MEDIAN EARNIN...          NaN
# 1                                                (X)          NaN
# 2                                                (X)          NaN
# 3                                                (X)          NaN
# 4                                                (X)          NaN
#
# [5 rows x 771 columns]

# %%
acs_s1501[['TRACT', 'COUNTY', 'STATE']] = acs_s1501.NAME.str.split(',', expand=True)

# %%
acs_s1501 = acs_s1501[acs_s1501['COUNTY'] == ' Fayette County']

# %%
acs_s1501['CENSUS_TRACT'] = acs_s1501.apply(lambda row: row['GEO_ID'][9:], axis = 1)

# %%
keep = ['S1501_C01_001E', 'S1501_C01_002E', 'S1501_C01_003E', 'S1501_C01_004E', 'S1501_C01_005E', 'S1501_C01_006E', 'S1501_C01_007E', 'S1501_C01_008E', 'S1501_C01_009E', 'S1501_C01_010E', 'S1501_C01_011E', 'S1501_C01_012E', 'S1501_C01_013E', 'S1501_C01_014E', 'S1501_C01_015E','CENSUS_TRACT']

# %%
rename = ['TOTAL_POP_18_24', 'TOTAL_POP_18_24_NO_HIGH_SCHOOL', 'TOTAL_POP_18_24_HIGH_SCHOOL', 'TOTAL_POP_18_24_SOME_COLLEGE', 'TOTAL_POP_18_24_SOME_BACHELORS_HIGHER', 'TOTAL_POP_25P', 'TOTAL_POP_25P_LESS_THAN_9TH', 'TOTAL_POP_25P_9TH_TO_12TH', 'TOTAL_POP_25P_HIGH_SCHOOL', 'TOTAL_POP_25P_SOME_COLLEGE', 'TOTAL_POP_25P_ASSOCIATES', 'TOTAL_POP_25P_BACHELORS', 'TOTAL_POP_25P_GRADUATE', 'TOTAL_POP_25P_HIGH_SCHOOL_HIGHER', 'TOTAL_POP_25P_BACHELORS_HIGHER','CENSUS_TRACT']

# %%
acs_s1501 = acs_s1501[keep]
acs_s1501.columns = rename

# %%
acs_s1901 = pd.read_csv('E:/CR2/Repos/TNC-Demand-Model-Southeast/Raw_Inputs/ACS/S1901/S1901.csv')

# %%
acs_s1901.head()
# Out:
#                  GEO_ID                                         NAME  \
# 0             Geography                         Geographic Area Name
# 1           0400000US21                                     Kentucky
# 2  1400000US21067000101  Census Tract 1.01, Fayette County, Kentucky
# 3  1400000US21067000102  Census Tract 1.02, Fayette County, Kentucky
# 4  1400000US21067000200     Census Tract 2, Fayette County, Kentucky
#
#                 S1901_C01_001E                      S1901_C01_001M  \
# 0  Estimate!!Households!!Total  Margin of Error!!Households!!Total
# 1                      1734618                                4886
# 2                         1993                                 120
# 3                          984                                 108
# 4                         1225                                 128
#
#                                    S1901_C01_002E  \
# 0  Estimate!!Households!!Total!!Less than $10,000
# 1                                             8.3
# 2                                            21.7
# 3                                            22.4
# 4                                            11.6
#
#                                       S1901_C01_002M  \
# 0  Margin of Error!!Households!!Total!!Less than ...
# 1                                                0.1
# 2                                                6.4
# 3                                                6.7
# 4                                                5.5
#
#                                     S1901_C01_003E  \
# 0  Estimate!!Households!!Total!!$10,000 to $14,999
# 1                                              5.8
# 2                                             10.9
# 3                                             16.9
# 4                                             10.3
#
#                                       S1901_C01_003M  \
# 0  Margin of Error!!Households!!Total!!$10,000 to...
# 1                                                0.1
# 2                                                5.3
# 3                                                6.7
# 4                                                6.0
#
#                                     S1901_C01_004E  \
# 0  Estimate!!Households!!Total!!$15,000 to $24,999
# 1                                             11.1
# 2                                             17.2
# 3                                              8.1
# 4                                             23.7
#
#                                       S1901_C01_004M  ...  \
# 0  Margin of Error!!Households!!Total!!$15,000 to...  ...
# 1                                                0.2  ...
# 2                                                4.7  ...
# 3                                                4.2  ...
# 4                                                6.7  ...
#
#                                       S1901_C04_012M  \
# 0  Margin of Error!!Nonfamily households!!Median ...
# 1                                                346
# 2                                               5252
# 3                                              12047
# 4                                               7920
#
#                                       S1901_C04_013E  \
# 0  Estimate!!Nonfamily households!!Mean income (d...
# 1                                              42778
# 2                                              36652
# 3                                              40063
# 4                                              40094
#
#                                       S1901_C04_013M  \
# 0  Margin of Error!!Nonfamily households!!Mean in...
# 1                                                512
# 2                                               6848
# 3                                               7826
# 4                                              10920
#
#                                       S1901_C04_014E  \
# 0  Estimate!!Nonfamily households!!PERCENT ALLOCA...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1901_C04_014M  \
# 0  Margin of Error!!Nonfamily households!!PERCENT...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1901_C04_015E  \
# 0  Estimate!!Nonfamily households!!PERCENT ALLOCA...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1901_C04_015M  \
# 0  Margin of Error!!Nonfamily households!!PERCENT...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S1901_C04_016E  \
# 0  Estimate!!Nonfamily households!!PERCENT ALLOCA...
# 1                                               31.8
# 2                                               21.7
# 3                                               28.2
# 4                                               31.3
#
#                                       S1901_C04_016M Unnamed: 130
# 0  Margin of Error!!Nonfamily households!!PERCENT...          NaN
# 1                                                (X)          NaN
# 2                                                (X)          NaN
# 3                                                (X)          NaN
# 4                                                (X)          NaN
#
# [5 rows x 131 columns]

# %%
acs_s1901[['TRACT', 'COUNTY', 'STATE']] = acs_s1901.NAME.str.split(',', expand=True)

# %%
acs_s1901 = acs_s1901[acs_s1901['COUNTY'] == ' Fayette County']

# %%
acs_s1901['CENSUS_TRACT'] = acs_s1901.apply(lambda row: row['GEO_ID'][9:], axis = 1)

# %%
keep = ['S1901_C01_002E', 'S1901_C01_003E', 'S1901_C01_004E', 'S1901_C01_005E', 'S1901_C01_006E', 'S1901_C01_007E', 'S1901_C01_008E', 'S1901_C01_009E', 'S1901_C01_010E', 'S1901_C01_011E', 'S1901_C01_012E', 'S1901_C01_012E','CENSUS_TRACT']

# %%
rename = ['TOTAL_HHLDS_LESS_10K', 'TOTAL_HHLDS_10K_15K', 'TOTAL_HHLDS_15K_25K', 'TOTAL_HHLDS_25K_35K', 'TOTAL_HHLDS_35K_50K', 'TOTAL_HHLDS_50K_75K', 'TOTAL_HHLDS_75K_100K', 'TOTAL_HHLDS_100K_150K', 'TOTAL_HHLDS_150K_200K', 'TOTAL_HHLDS_200KP', 'HHLDS_MEDIAN_INCOME', 'HHLDS_MEAN_INCOME','CENSUS_TRACT']

# %%
acs_s1901 = acs_s1901[keep]
acs_s1901.columns = rename

# %%
#THIS ALL NEEDS TO GO IN THE MAIN SCRIPT

acs = acs_dp05.merge(acs_s1101, on = 'CENSUS_TRACT', suffixes = ('_DP05', '_S1101'))
acs = acs.merge(acs_s1501, on = 'CENSUS_TRACT', suffixes = ('', '_S1501'))
acs = acs.merge(acs_s1901, on = 'CENSUS_TRACT', suffixes = ('', '_S1901'))
acs = acs.merge(acs_dp04, on = 'CENSUS_TRACT', suffixes = ('', '_DP04'))

# %%
acs.head()
# Out:
#   TOTAL_POP TOTAL_MALE TOTAL_FEMALE AGE_5U AGE_5_9 AGE+10_14 AGE_15_19  \
# 0      3171       1835         1336    100      50        36        97
# 1      1546        838          708     51      59        22        20
# 2      3839       2059         1780    129     136       185       815
# 3      2716       1262         1454    145     168       138       151
# 4      1960        831         1129    218     164       149       126
#
#   AGE_20_24 AGE_25_34 AGE_35_44  ... TOTAL_HHLDS_150K_200K TOTAL_HHLDS_200KP  \
# 0       752       727       371  ...                   3.6               5.0
# 1        20       281       189  ...                   2.3               4.8
# 2       749       521       250  ...                   0.0               4.2
# 3       203       446       456  ...                   0.7               1.3
# 4       103       316       265  ...                   0.0               0.4
#
#   HHLDS_MEDIAN_INCOME HHLDS_MEAN_INCOME TOTAL_HHLDS_DP04 HHLDS_0_VEH  \
# 0               25363             25363           1993.0       646.0
# 1               26477             26477            984.0       323.0
# 2               26725             26725           1225.0       355.0
# 3               32089             32089           1249.0       227.0
# 4               27031             27031            784.0       215.0
#
#   HHLDS_1_VEH HHLDS_2_VEH HHLDS_3P_VEH AVG_VEH_PER_HHLD
# 0       950.0       358.0         39.0         0.894631
# 1       478.0       129.0         54.0         0.912602
# 2       449.0       290.0        131.0         1.160816
# 3       595.0       307.0        120.0         1.256205
# 4       321.0       186.0         62.0         1.121173
#
# [5 rows x 54 columns]

# %%
#THIS ALL NEEDS TO GO IN THE MAIN SCRIPT

variables = acs.columns.drop('CENSUS_TRACT')

# %%
#THIS ALL NEEDS TO GO IN THE MAIN SCRIPT


for var in variables:    
    acs[var] = acs[var].replace('-',np.nan)
    acs[var] = acs[var].replace('250,000+','250000')
    acs[var] = acs[var].astype(float)

# %%
#THIS ALL NEEDS TO GO IN THE MAIN SCRIPT


acs.to_csv('../Raw_Inputs/ACS/Merged_ACS/ACS.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[79], line 4
#       1 #THIS ALL NEEDS TO GO IN THE MAIN SCRIPT
# ----> 4 acs.to_csv('../Raw_Inputs/ACS/Merged_ACS/ACS.csv')
#
# File ~\anaconda3\envs\cr2\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\cr2\Lib\site-packages\pandas\core\generic.py:3964, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3953 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3955 formatter = DataFrameFormatter(
#    3956     frame=df,
#    3957     header=header,
#    (...)
#    3961     decimal=decimal,
#    3962 )
# -> 3964 return DataFrameRenderer(formatter).to_csv(
#    3965     path_or_buf,
#    3966     lineterminator=lineterminator,
#    3967     sep=sep,
#    3968     encoding=encoding,
#    3969     errors=errors,
#    3970     compression=compression,
#    3971     quoting=quoting,
#    3972     columns=columns,
#    3973     index_label=index_label,
#    3974     mode=mode,
#    3975     chunksize=chunksize,
#    3976     quotechar=quotechar,
#    3977     date_format=date_format,
#    3978     doublequote=doublequote,
#    3979     escapechar=escapechar,
#    3980     storage_options=storage_options,
#    3981 )
#
# File ~\anaconda3\envs\cr2\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\envs\cr2\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\anaconda3\envs\cr2\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\envs\cr2\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..\Raw_Inputs\ACS\Merged_ACS'
