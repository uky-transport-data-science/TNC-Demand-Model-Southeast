# %%
import geopandas as gp
import pandas as pd
import numpy as np
import os

# %%
## Set working directory
os.chdir('E:/CR2/Repos/TNC-Demand-Model-Southeast/')

# %%
tracts = gp.read_file('Raw_Inputs/Shapefile Centroids/kentucky_census_centroids.shp')
tracts
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID    NAME             NAMELSAD  \
# 0         21      095  971300  21095971300    9713    Census Tract 9713
# 1         21      211  040302  21211040302  403.02  Census Tract 403.02
# 2         21      185  030301  21185030301  303.01  Census Tract 303.01
# 3         21      107  970600  21107970600    9706    Census Tract 9706
# 4         21      193  971000  21193971000    9710    Census Tract 9710
# ...      ...      ...     ...          ...     ...                  ...
# 1301      21      067  000900  21067000900       9       Census Tract 9
# 1302      21      073  070401  21073070401  704.01  Census Tract 704.01
# 1303      21      015  070311  21015070311  703.11  Census Tract 703.11
# 1304      21      015  070314  21015070314  703.14  Census Tract 703.14
# 1305      21      025  920200  21025920200    9202    Census Tract 9202
#
#       MTFCC FUNCSTAT      ALAND   AWATER     INTPTLAT      INTPTLON  \
# ...

# %%
# keep only the X and Y coordinates of each Census tract row

# %%
origins = pd.DataFrame()
origins['X'] = tracts.Centroid_X
origins['Y'] = tracts.Centroid_Y

# %%
origins['GEOID'] = tracts.GEOID

# %%
origins.head()
# Out:
#            X          Y        GEOID
# 0 -83.300179  36.753668  21095971300
# 1 -85.225651  38.206670  21211040302
# 2 -85.405882  38.414447  21185030301
# 3 -87.484726  37.321770  21107970600
# 4 -83.388587  37.323309  21193971000

# %%
origins.to_csv('Cleaned_Inputs/Intermediate/centroid_points.csv')
