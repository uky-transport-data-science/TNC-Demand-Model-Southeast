# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns= 1000

# %%
pred = pd.read_csv('E:/CR2/Repos/TNC-Demand-Model-Southeast/Cleaned_Inputs/Intermediate/pred_trips.csv')

# %%
pred['TOTAL_TRIPS'] = pred['NT_PRED_AVG_WD_PICKUPS'] + pred['AM_PRED_AVG_WD_PICKUPS'] + pred['MD_PRED_AVG_WD_PICKUPS'] + pred['PM_PRED_AVG_WD_PICKUPS'] + pred['EV_PRED_AVG_WD_PICKUPS']

# %%
total_trips = pred['TOTAL_TRIPS'].sum()
total_trips
# Out:
# 76.07580003488086

# %%
# total predicted trips on a weekday in 2019 FAYETTE KY

# %%
pred.tail(15)
# Out:
#     Unnamed: 0      GEOID20  MEDIAN_AGE  LOW_INC_0  HI_INC_0  LOW_INC_1P  \
# 67          67  21067004003        33.1      135.0      35.0      1910.0
# 68          68  21067004005        45.3        0.0       0.0       286.0
# 69          69  21067004006        48.0        0.0       0.0       125.0
# 70          70  21067004007        50.1       10.0       0.0       432.0
# 71          71  21067004103        30.1       33.0       0.0       653.0
# 72          72  21067004104        35.8      345.0       0.0      1395.0
# 73          73  21067004105        37.9       30.0      10.0      1175.0
# 74          74  21067004106        36.8       10.0       0.0       779.0
# 75          75  21067004107        36.9        4.0       0.0      1035.0
# 76          76  21067004204        38.2       20.0       0.0      1730.0
# 77          77  21067004205        42.9        0.0       0.0      1265.0
# 78          78  21067004207        49.1        0.0       0.0       620.0
# ...
