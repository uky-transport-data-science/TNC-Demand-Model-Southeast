# %%
import pandas as pd
import numpy as py

# %%
wac = pd.read_csv('../Cleaned_Inputs/Intermediate/wac.csv')

# %%
acs = pd.read_csv('E:/CR2/Repos/TNC-Demand-Model-Southeast/Cleaned_Inputs/Intermediate/acs.csv')

# %%
wac.tail()
# Out:
#      Unnamed: 0         trct         w_geocode  C000  CA01  CA02  CA03  CE01  \
# 105         105  21021930500  9039430115077260  4727   914  2549  1264   690
# 106         106  21021930600  6727017792065073   205    53    97    55    78
# 107         107  21021930700  5255482675056338   148    40    80    28    33
# 108         108  21023950100  5886706028043210   490    85   273   132   104
# 109         109  21023950200  4204790040029745    91    18    46    27    21
#
#      CE02  CE03  ...  stanrcname    necta  nectaname  mil  milname  \
# 105  1743  2294  ...         0.0  4299957        0.0  0.0        0
# 106    79    48  ...         0.0  3199968        0.0  0.0        0
# 107    71    44  ...         0.0  2499975        0.0  0.0        0
# 108   158   228  ...         0.0  2799972        0.0  0.0        0
# 109    21    49  ...         0.0  1999980        0.0  0.0        0
#
#                                                  stwib  \
# ...

# %%
acs.head()
# Out:
#    Unnamed: 0  MEDIAN_AGE  CENSUS_TRACT  TOTAL_HHLDS  AVG_HHLD_SIZE  \
# 0           0        31.0   21067000101         1993           1.52
# 1           1        52.4   21067000102          984           1.44
# 2           2        24.1   21067000200         1225           2.37
# 3           3        36.8   21067000300         1249           2.17
# 4           4        32.8   21067000400          784           2.48
#
#    AVG_FAMILY_SIZE  TOTAL_POP_18_24  TOTAL_POP_18_24_NO_HIGH_SCHOOL  \
# 0             2.40              820                              14
# 1             2.70               20                               0
# 2             3.33             1416                              13
# 3             2.89              230                              45
# 4             3.12              146                              13
#
#    TOTAL_POP_18_24_HIGH_SCHOOL  TOTAL_POP_18_24_SOME_COLLEGE  ...  \
# 0                           86                           510  ...
# ...
