# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
pd.options.display.max_columns= 100

# %%
wac = pd.read_csv('../Raw_Inputs/LEHD/ky_wac_S000_JT00_2019.csv')

# %%
geo = pd.read_csv('../Raw_Inputs/LEHD/ky_xwalk.csv', low_memory=False)

# %%
geo[['COUNTY', 'STATE']] = geo.ctyname.str.split(',', expand=True)

# %%
geo.head()
# Out:
#         tabblk2020  st stusps    stname    cty                ctyname  \
# 0  212270118011011  21     KY  Kentucky  21227      Warren County, KY
# 1  210579501002098  21     KY  Kentucky  21057  Cumberland County, KY
# 2  211639703012010  21     KY  Kentucky  21163       Meade County, KY
# 3  212019701001005  21     KY  Kentucky  21201   Robertson County, KY
# 4  211679603002041  21     KY  Kentucky  21167      Mercer County, KY
#
#           trct               trctname          bgrp  \
# 0  21227011801    118.01 (Warren, KY)  212270118011
# 1  21057950100  9501 (Cumberland, KY)  210579501002
# 2  21163970301    9703.01 (Meade, KY)  211639703012
# 3  21201970100   9701 (Robertson, KY)  212019701001
# 4  21167960300      9603 (Mercer, KY)  211679603002
#
#                          bgrpname   cbsa                     cbsaname   zcta  \
# 0    1 (Tract 118.01, Warren, KY)  14540            Bowling Green, KY  42101
# 1  2 (Tract 9501, Cumberland, KY)  99999                          NaN  42717
# 2    2 (Tract 9703.01, Meade, KY)  21060  Elizabethtown-Fort Knox, KY  40117
# 3   1 (Tract 9701, Robertson, KY)  99999                          NaN  41044
# 4      2 (Tract 9603, Mercer, KY)  99999                          NaN  40330
#
#    zctaname    stplc stplcname     ctycsub                       ctycsubname  \
# 0   42101.0  9999999       NaN  2122791488      Greencastle CCD (Warren, KY)
# 1   42717.0  9999999       NaN  2105790432  Burkesville CCD (Cumberland, KY)
# 2   40117.0  9999999       NaN  2116391248          Flaherty CCD (Meade, KY)
# 3   41044.0  9999999       NaN  2120192408  Mount Olivet CCD (Robertson, KY)
# 4   40330.0  9999999       NaN  2116791624      Harrodsburg CCD (Mercer, KY)
#
#    stcd116 stcd116name  stsldl                   stsldlname  stsldu  \
# 0     2102       KY-02   21019  State House District 19, KY   21032
# 1     2101       KY-01   21083  State House District 83, KY   21016
# 2     2102       KY-02   21027  State House District 27, KY   21005
# 3     2106       KY-06   21070  State House District 70, KY   21027
# 4     2102       KY-02   21055  State House District 55, KY   21022
#
#                      stslduname  stschool  \
# 0  State Senate District 32, KY   2105730
# 1  State Senate District 16, KY   2101410
# 2   State Senate District 5, KY   2104050
# 3  State Senate District 27, KY   2105040
# 4  State Senate District 22, KY   2104110
#
#                             stschoolname  stsecon stseconname   trib  \
# 0      Warren County School District, KY  9999999         NaN  99999
# 1  Cumberland County School District, KY  9999999         NaN  99999
# 2       Meade County School District, KY  9999999         NaN  99999
# 3   Robertson County School District, KY  9999999         NaN  99999
# 4      Mercer County School District, KY  9999999         NaN  99999
#
#    tribname     tsub  tsubname   stanrc  stanrcname  necta  nectaname  mil  \
# 0       NaN  9999999       NaN  9999999         NaN  99999        NaN  NaN
# 1       NaN  9999999       NaN  9999999         NaN  99999        NaN  NaN
# 2       NaN  9999999       NaN  9999999         NaN  99999        NaN  NaN
# 3       NaN  9999999       NaN  9999999         NaN  99999        NaN  NaN
# 4       NaN  9999999       NaN  9999999         NaN  99999        NaN  NaN
#
#   milname     stwib            stwibname   blklatdd   blklondd  createdate  \
# 0     NaN  2121000K   K Barren River WIB  37.119387 -86.458770    20231016
# 1     NaN  2121000H    H Cumberlands WIB  36.759793 -85.477314    20231016
# 2     NaN  2121000B  B Lincoln Trail WIB  37.888709 -86.115484    20231016
# 3     NaN  2121000F          F Tenco WIB  38.560171 -84.004546    20231016
# 4     NaN  2121000I      I Bluegrass WIB  37.727052 -84.968578    20231016
#
#               COUNTY STATE
# 0      Warren County    KY
# 1  Cumberland County    KY
# 2       Meade County    KY
# 3   Robertson County    KY
# 4      Mercer County    KY

# %%
geo_xwalk = geo[geo['COUNTY'] == ' Fayette County']

# %%
geo_xwalk.head()
# Out:
# Empty DataFrame
# Columns: [tabblk2020, st, stusps, stname, cty, ctyname, trct, trctname, bgrp, bgrpname, cbsa, cbsaname, zcta, zctaname, stplc, stplcname, ctycsub, ctycsubname, stcd116, stcd116name, stsldl, stsldlname, stsldu, stslduname, stschool, stschoolname, stsecon, stseconname, trib, tribname, tsub, tsubname, stanrc, stanrcname, necta, nectaname, mil, milname, stwib, stwibname, blklatdd, blklondd, createdate, COUNTY, STATE]
# Index: []

# %%
wac_geo = wac.merge(geo_xwalk, how="left", left_on='w_geocode', right_on='tabblk2020')

# %%
wac_geo_grouped = wac_geo.groupby(by = 'trct', as_index = False).sum()

# %%
wac_geo_grouped['FOOD_EMP'] = wac_geo_grouped['CNS18']

# %%
wac_geo_grouped['RETAIL_EMP'] = wac_geo_grouped['CNS07']

# %%
wac_geo_grouped['OTHER_EMP'] = wac_geo_grouped['CNS01'] + wac_geo_grouped['CNS02'] + wac_geo_grouped['CNS03'] + wac_geo_grouped['CNS04'] + wac_geo_grouped['CNS05'] + wac_geo_grouped['CNS06'] + wac_geo_grouped['CNS08'] + wac_geo_grouped['CNS09'] + wac_geo_grouped['CNS10'] + wac_geo_grouped['CNS11'] + wac_geo_grouped['CNS12'] + wac_geo_grouped['CNS13'] + wac_geo_grouped['CNS14'] + wac_geo_grouped['CNS15'] + wac_geo_grouped['CNS16'] + wac_geo_grouped['CNS17'] + wac_geo_grouped['CNS19'] + wac_geo_grouped['CNS20']

# %%
wac_geo_grouped['TOTAL_EMP_DEN'] = wac_geo_grouped['C000'] / 283.9

# %%
wac_geo_grouped = wac_geo_grouped[['trct', 'COUNTY', 'FOOD_EMP', 'RETAIL_EMP', 'OTHER_EMP', 'TOTAL_EMP_DEN']]

# %%
wac_geo_grouped.head()

# %%
wac_geo_grouped.to_csv('../Cleaned_Inputs/Intermediate/wac.csv')
